# %%
# Import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Create a set of random latitude and longitude 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and lonitudes to a list 
coordinates = lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 590

# %%
# Import the requests library. 
import requests

# Import the API Key. 
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
time.sleep(60)

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ossora
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | namie
# Processing Record 5 of Set 1 | buala
# Processing Record 6 of Set 1 | sabang
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | tual
# Processing Record 9 of Set 1 | barraute
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | souillac
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | sibolga
# Processing Record 18 of Set 1 | tinskoy
# Processing Record 19 of Set 1 | muli
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | umm lajj
# Processing Record 22 of Set 1 | hillsborough
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto palomas
# Processing Record 27 of Set 1 | rawson
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | changping
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | auki
# Processing Record 32 of Set 1 | kidal
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | alugan
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | mehamn
# Processing Record 39 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | shalya
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | bereda
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | shepsi
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | anadyr
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | ghatanji
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | saiha
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | morogoro
# Processing Record 6 of Set 2 | brandon
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | trenggalek
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | kamina
# Processing Record 14 of Set 2 | bambanglipuro
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | birao
# Processing Record 17 of Set 2 | sobolevo
# Processing Record 18 of Set 2 | buraydah
# Processing Record 19 of Set 2 | yashkul
# Processing Record 20 of Set 2 | isangel
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | meulaboh
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | kinwat
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | ahipara
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | lethem
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | verkhnyaya inta
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | saint-francois
# Processing Record 37 of Set 2 | simbahan
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | pithiviers
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | broken hill
# Processing Record 45 of Set 2 | san quintin
# Processing Record 46 of Set 2 | bubaque
# Processing Record 47 of Set 2 | ternate
# Processing Record 48 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | poum
# Processing Record 1 of Set 3 | newport
# Processing Record 2 of Set 3 | puerto leguizamo
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | torma
# Processing Record 5 of Set 3 | batemans bay
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | araouane
# Processing Record 8 of Set 3 | labuhan
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 11 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 3 | craig
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | nanortalik
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | lima
# Processing Record 20 of Set 3 | vaini
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | north augusta
# Processing Record 23 of Set 3 | malakal
# Processing Record 24 of Set 3 | leshukonskoye
# Processing Record 25 of Set 3 | taunggyi
# Processing Record 26 of Set 3 | dunedin
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | faya
# Processing Record 32 of Set 3 | karratha
# Processing Record 33 of Set 3 | jodhpur
# Processing Record 34 of Set 3 | benguela
# Processing Record 35 of Set 3 | talara
# Processing Record 36 of Set 3 | termini imerese
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | gurgentepe
# Processing Record 39 of Set 3 | soyo
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | kamaishi
# Processing Record 42 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 3 | sebaco
# Processing Record 44 of Set 3 | mareeba
# Processing Record 45 of Set 3 | xuddur
# Processing Record 46 of Set 3 | marawi
# Processing Record 47 of Set 3 | indramayu
# Processing Record 48 of Set 3 | yautepec
# Processing Record 49 of Set 3 | la ronge
# Processing Record 50 of Set 3 | zarubino
# Processing Record 1 of Set 4 | bairnsdale
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | yarada
# Processing Record 4 of Set 4 | port blair
# Processing Record 5 of Set 4 | stokmarknes
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | kieta
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | hare bay
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | gayeri
# Processing Record 12 of Set 4 | spassk
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | vila velha
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | tanda
# Processing Record 18 of Set 4 | bonavista
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | ransang
# Processing Record 23 of Set 4 | tazovskiy
# Processing Record 24 of Set 4 | balkhash
# Processing Record 25 of Set 4 | bara
# Processing Record 26 of Set 4 | ampanihy
# Processing Record 27 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 28 of Set 4 | mount isa
# Processing Record 29 of Set 4 | mount pleasant
# Processing Record 30 of Set 4 | kasimov
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | cockburn town
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | vostok
# Processing Record 35 of Set 4 | hami
# Processing Record 36 of Set 4 | cabinda
# Processing Record 37 of Set 4 | islamkot
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | bajil
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 4 | oudtshoorn
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | chapais
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | goderich
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | ketchikan
# Processing Record 49 of Set 4 | itapirapua
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | teluk nibung
# Processing Record 2 of Set 5 | soverato
# Processing Record 3 of Set 5 | sheridan
# Processing Record 4 of Set 5 | krasnyy chikoy
# Processing Record 5 of Set 5 | yarmouth
# Processing Record 6 of Set 5 | kiryas joel
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | skjervoy
# Processing Record 9 of Set 5 | winnemucca
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | phangnga
# Processing Record 12 of Set 5 | srednekolymsk
# Processing Record 13 of Set 5 | uberaba
# Processing Record 14 of Set 5 | lavrentiya
# Processing Record 15 of Set 5 | katsuura
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | iquique
# Processing Record 20 of Set 5 | tasiilaq
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | seymchan
# Processing Record 23 of Set 5 | taywarah
# Processing Record 24 of Set 5 | kulhudhuffushi
# Processing Record 25 of Set 5 | moramanga
# Processing Record 26 of Set 5 | varzea alegre
# Processing Record 27 of Set 5 | ust-nera
# Processing Record 28 of Set 5 | kodiak
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | sept-iles
# Processing Record 31 of Set 5 | feijo
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | kwinana
# Processing Record 36 of Set 5 | minas
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | salamanca
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | turkistan
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | kolpashevo
# Processing Record 43 of Set 5 | northam
# Processing Record 44 of Set 5 | oranjemund
# Processing Record 45 of Set 5 | ciudad bolivar
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | contamana
# Processing Record 48 of Set 5 | nyurba
# Processing Record 49 of Set 5 | mayo
# Processing Record 50 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 6 | langham
# Processing Record 2 of Set 6 | yar-sale
# Processing Record 3 of Set 6 | boa vista
# Processing Record 4 of Set 6 | banda aceh
# Processing Record 5 of Set 6 | kanniyakumari
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | ostrovskoye
# Processing Record 8 of Set 6 | gornyy
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | sambava
# Processing Record 11 of Set 6 | gizo
# Processing Record 12 of Set 6 | vermilion
# Processing Record 13 of Set 6 | morgan city
# Processing Record 14 of Set 6 | kahului
# Processing Record 15 of Set 6 | moissac
# Processing Record 16 of Set 6 | taoudenni
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | churumuco
# City not found. Skipping...
# Processing Record 19 of Set 6 | junin
# Processing Record 20 of Set 6 | vung tau
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | georgetown
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | kruisfontein
# Processing Record 27 of Set 6 | monforte de lemos
# Processing Record 28 of Set 6 | yulara
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 6 | itaituba
# Processing Record 32 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 6 | hamilton
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | laguna
# Processing Record 36 of Set 6 | kathu
# Processing Record 37 of Set 6 | borujerd
# Processing Record 38 of Set 6 | nishihara
# Processing Record 39 of Set 6 | kaoma
# Processing Record 40 of Set 6 | staryy nadym
# Processing Record 41 of Set 6 | kaohsiung
# Processing Record 42 of Set 6 | manaus
# Processing Record 43 of Set 6 | sao miguel do araguaia
# Processing Record 44 of Set 6 | rab
# City not found. Skipping...
# Processing Record 45 of Set 6 | uk
# City not found. Skipping...
# Processing Record 46 of Set 6 | carutapera
# Processing Record 47 of Set 6 | luanda
# Processing Record 48 of Set 6 | bay city
# Processing Record 49 of Set 6 | pochutla
# Processing Record 50 of Set 6 | las palmas
# Processing Record 1 of Set 7 | berlevag
# Processing Record 2 of Set 7 | talas
# Processing Record 3 of Set 7 | sikonge
# Processing Record 4 of Set 7 | arraial do cabo
# Processing Record 5 of Set 7 | minab
# Processing Record 6 of Set 7 | hearst
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | praia da vitoria
# Processing Record 9 of Set 7 | yaan
# Processing Record 10 of Set 7 | cordoba
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | longhua
# Processing Record 14 of Set 7 | holme
# Processing Record 15 of Set 7 | bahia de caraquez
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 7 | tiznit
# Processing Record 20 of Set 7 | iqaluit
# Processing Record 21 of Set 7 | nantucket
# Processing Record 22 of Set 7 | tambopata
# Processing Record 23 of Set 7 | abnub
# Processing Record 24 of Set 7 | flinders
# Processing Record 25 of Set 7 | bonthe
# Processing Record 26 of Set 7 | cedar city
# Processing Record 27 of Set 7 | norman wells
# Processing Record 28 of Set 7 | rocha
# Processing Record 29 of Set 7 | jinxiang
# Processing Record 30 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | lodwar
# Processing Record 34 of Set 7 | tura
# Processing Record 35 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 7 | karaton
# Processing Record 37 of Set 7 | padang
# Processing Record 38 of Set 7 | senador guiomard
# Processing Record 39 of Set 7 | lamar
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | tiarei
# Processing Record 42 of Set 7 | nachalovo
# Processing Record 43 of Set 7 | cayenne
# Processing Record 44 of Set 7 | samarai
# Processing Record 45 of Set 7 | abu samrah
# Processing Record 46 of Set 7 | lindi
# Processing Record 47 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 7 | mwinilunga
# Processing Record 49 of Set 7 | shingu
# Processing Record 50 of Set 7 | dombarovskiy
# Processing Record 1 of Set 8 | kuanshan
# City not found. Skipping...
# Processing Record 2 of Set 8 | daragutan
# Processing Record 3 of Set 8 | evensk
# Processing Record 4 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 8 | riverton
# Processing Record 7 of Set 8 | dawlatabad
# Processing Record 8 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | grand gaube
# Processing Record 10 of Set 8 | vanavara
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | tonneins
# Processing Record 13 of Set 8 | balanacan
# Processing Record 14 of Set 8 | rocky mountain house
# Processing Record 15 of Set 8 | mountain home
# Processing Record 16 of Set 8 | plettenberg bay
# Processing Record 17 of Set 8 | shelburne
# Processing Record 18 of Set 8 | suratgarh
# Processing Record 19 of Set 8 | makung
# City not found. Skipping...
# Processing Record 20 of Set 8 | mandera
# Processing Record 21 of Set 8 | zhigansk
# Processing Record 22 of Set 8 | leh
# Processing Record 23 of Set 8 | lieksa
# Processing Record 24 of Set 8 | kirakira
# Processing Record 25 of Set 8 | rindal
# Processing Record 26 of Set 8 | shimanovsk
# Processing Record 27 of Set 8 | joensuu
# Processing Record 28 of Set 8 | rosiori
# Processing Record 29 of Set 8 | kokopo
# Processing Record 30 of Set 8 | inhambane
# Processing Record 31 of Set 8 | coahuayana
# Processing Record 32 of Set 8 | khandbari
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | qasigiannguit
# Processing Record 35 of Set 8 | mumford
# Processing Record 36 of Set 8 | hohhot
# Processing Record 37 of Set 8 | darhan
# Processing Record 38 of Set 8 | caravelas
# Processing Record 39 of Set 8 | kenora
# Processing Record 40 of Set 8 | ennis
# Processing Record 41 of Set 8 | zhezkazgan
# Processing Record 42 of Set 8 | alice springs
# Processing Record 43 of Set 8 | sokoni
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | russell
# Processing Record 47 of Set 8 | viedma
# Processing Record 48 of Set 8 | cherskiy
# Processing Record 49 of Set 8 | ouesso
# Processing Record 50 of Set 8 | shenjiamen
# Processing Record 1 of Set 9 | talnakh
# Processing Record 2 of Set 9 | tulun
# Processing Record 3 of Set 9 | itaqui
# Processing Record 4 of Set 9 | hendek
# Processing Record 5 of Set 9 | quatre cocos
# Processing Record 6 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 9 | san isidro
# Processing Record 10 of Set 9 | half moon bay
# Processing Record 11 of Set 9 | sosnogorsk
# Processing Record 12 of Set 9 | teya
# Processing Record 13 of Set 9 | benghazi
# Processing Record 14 of Set 9 | awbari
# Processing Record 15 of Set 9 | ewa beach
# Processing Record 16 of Set 9 | bakhmach
# Processing Record 17 of Set 9 | garowe
# Processing Record 18 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 9 | greensburg
# Processing Record 20 of Set 9 | vestmannaeyjar
# Processing Record 21 of Set 9 | goiatuba
# Processing Record 22 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 9 | san fernando
# Processing Record 25 of Set 9 | sur
# Processing Record 26 of Set 9 | saint-leu
# Processing Record 27 of Set 9 | kesennuma
# City not found. Skipping...
# Processing Record 28 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 9 | north bend
# Processing Record 30 of Set 9 | baijiantan
# Processing Record 31 of Set 9 | edeia
# Processing Record 32 of Set 9 | luwuk
# Processing Record 33 of Set 9 | iracoubo
# Processing Record 34 of Set 9 | tororo
# Processing Record 35 of Set 9 | camana
# Processing Record 36 of Set 9 | phan thiet
# Processing Record 37 of Set 9 | moussoro
# Processing Record 38 of Set 9 | lagoa
# Processing Record 39 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 9 | manbij
# Processing Record 41 of Set 9 | marsh harbour
# Processing Record 42 of Set 9 | usogorsk
# Processing Record 43 of Set 9 | oktyabrskoye
# Processing Record 44 of Set 9 | viisoara
# Processing Record 45 of Set 9 | sao filipe
# Processing Record 46 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 47 of Set 9 | kizema
# Processing Record 48 of Set 9 | ath
# Processing Record 49 of Set 9 | aracoiaba da serra
# Processing Record 50 of Set 9 | cairns
# Processing Record 1 of Set 10 | walvis bay
# Processing Record 2 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 10 | comodoro rivadavia
# Processing Record 4 of Set 10 | cap malheureux
# Processing Record 5 of Set 10 | vila franca do campo
# Processing Record 6 of Set 10 | mbandaka
# Processing Record 7 of Set 10 | methoni
# Processing Record 8 of Set 10 | kirillov
# Processing Record 9 of Set 10 | san carlos de bariloche
# Processing Record 10 of Set 10 | vaitape
# Processing Record 11 of Set 10 | ati
# Processing Record 12 of Set 10 | lalmohan
# Processing Record 13 of Set 10 | montepuez
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | tamandare
# Processing Record 16 of Set 10 | khorixas
# Processing Record 17 of Set 10 | provideniya
# Processing Record 18 of Set 10 | serebryansk
# Processing Record 19 of Set 10 | esik
# Processing Record 20 of Set 10 | kendari
# Processing Record 21 of Set 10 | harper
# Processing Record 22 of Set 10 | clearwater
# Processing Record 23 of Set 10 | panaba
# Processing Record 24 of Set 10 | lasa
# Processing Record 25 of Set 10 | kizhinga
# Processing Record 26 of Set 10 | upata
# Processing Record 27 of Set 10 | alexandria
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | sampit
# Processing Record 30 of Set 10 | nichinan
# Processing Record 31 of Set 10 | muzhi
# Processing Record 32 of Set 10 | ozu
# Processing Record 33 of Set 10 | asyut
# Processing Record 34 of Set 10 | playa vicente
# Processing Record 35 of Set 10 | bingol
# Processing Record 36 of Set 10 | jardim
# Processing Record 37 of Set 10 | acajutla
# Processing Record 38 of Set 10 | ikom
# Processing Record 39 of Set 10 | bagn
# Processing Record 40 of Set 10 | gogrial
# Processing Record 41 of Set 10 | divnogorsk
# Processing Record 42 of Set 10 | sungaipenuh
# Processing Record 43 of Set 10 | gawler
# Processing Record 44 of Set 10 | tibati
# Processing Record 45 of Set 10 | joshimath
# Processing Record 46 of Set 10 | maniitsoq
# Processing Record 47 of Set 10 | wadena
# Processing Record 48 of Set 10 | puerto cabezas
# Processing Record 49 of Set 10 | podporozhye
# Processing Record 50 of Set 10 | winneba
# Processing Record 1 of Set 11 | jos
# Processing Record 2 of Set 11 | turbat
# Processing Record 3 of Set 11 | rozhyshche
# Processing Record 4 of Set 11 | bintulu
# Processing Record 5 of Set 11 | lexington
# Processing Record 6 of Set 11 | mantua
# Processing Record 7 of Set 11 | hailun
# Processing Record 8 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 11 | peto
# Processing Record 10 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 11 of Set 11 | elda
# Processing Record 12 of Set 11 | bairiki
# Processing Record 13 of Set 11 | kodinsk
# Processing Record 14 of Set 11 | okhotsk
# Processing Record 15 of Set 11 | rangapara
# Processing Record 16 of Set 11 | saurimo
# Processing Record 17 of Set 11 | kropotkin
# Processing Record 18 of Set 11 | chulumani
# Processing Record 19 of Set 11 | nivala
# Processing Record 20 of Set 11 | onguday
# Processing Record 21 of Set 11 | udomlya
# Processing Record 22 of Set 11 | kollo
# Processing Record 23 of Set 11 | tongliao
# Processing Record 24 of Set 11 | cedral
# Processing Record 25 of Set 11 | lashio
# Processing Record 26 of Set 11 | san angelo
# Processing Record 27 of Set 11 | yerbogachen
# Processing Record 28 of Set 11 | humaita
# Processing Record 29 of Set 11 | kamenka
# Processing Record 30 of Set 11 | tigil
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | kysyl-syr
# Processing Record 33 of Set 11 | pak phanang
# Processing Record 34 of Set 11 | hashtgerd
# Processing Record 35 of Set 11 | satinka
# Processing Record 36 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 11 | himora
# City not found. Skipping...
# Processing Record 38 of Set 11 | dosso
# Processing Record 39 of Set 11 | genthin
# Processing Record 40 of Set 11 | iquitos
# Processing Record 41 of Set 11 | kongolo
# Processing Record 42 of Set 11 | zalari
# Processing Record 43 of Set 11 | yuxia
# Processing Record 44 of Set 11 | mackenzie
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | belyy yar
# Processing Record 49 of Set 11 | portland
# Processing Record 50 of Set 11 | bridlington
# Processing Record 1 of Set 12 | warmbad
# Processing Record 2 of Set 12 | keita
# Processing Record 3 of Set 12 | novaya zaimka
# Processing Record 4 of Set 12 | santa isabel do rio negro
# Processing Record 5 of Set 12 | kaabong
# Processing Record 6 of Set 12 | burnie
# Processing Record 7 of Set 12 | sinnamary
# Processing Record 8 of Set 12 | santa fe
# Processing Record 9 of Set 12 | hervey bay
# Processing Record 10 of Set 12 | brae
# Processing Record 11 of Set 12 | deputatskiy
# Processing Record 12 of Set 12 | korla
# Processing Record 13 of Set 12 | ashland
# Processing Record 14 of Set 12 | naze
# Processing Record 15 of Set 12 | caceres
# Processing Record 16 of Set 12 | la libertad
# Processing Record 17 of Set 12 | kamarion
# Processing Record 18 of Set 12 | limenaria
# Processing Record 19 of Set 12 | mezhevoy
# Processing Record 20 of Set 12 | kostomuksha
# Processing Record 21 of Set 12 | chicama
# Processing Record 22 of Set 12 | key biscayne
# Processing Record 23 of Set 12 | san juan de la maguana
# Processing Record 24 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 12 | san roque
# Processing Record 26 of Set 12 | suicheng
# Processing Record 27 of Set 12 | henties bay
# Processing Record 28 of Set 12 | vanimo
# Processing Record 29 of Set 12 | aktas
# Processing Record 30 of Set 12 | honningsvag
# Processing Record 31 of Set 12 | masingbi
# Processing Record 32 of Set 12 | ekhabi
# Processing Record 33 of Set 12 | taltal
# Processing Record 34 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 12 | krasnoselkup
# Processing Record 36 of Set 12 | liverpool
# Processing Record 37 of Set 12 | manjacaze
# Processing Record 38 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 12 | redmond
# Processing Record 40 of Set 12 | cubara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionares to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ossora  59.2353  163.0719     19.47        77          20        2.04
# 1  Jamestown  42.0970  -79.2353     31.59        71         100       14.97
# 2       Chuy -33.6971  -53.4616     65.44        76          39       10.02
# 3      Namie  37.4833  141.0000     57.97        62         100       10.87
# 4      Buala  -8.1450  159.5921     80.78        82         100        9.84
# 5     Sabang   5.8933   95.3214     82.40        75          17        1.54
# 6       Tual  -5.6667  132.7500     82.24        76         100       12.82
# 7   Barraute  48.4335  -77.6328     19.67        93         100       12.62
# 8    Itarema  -2.9248  -39.9167     75.69        91         100        7.23
# 9   Khatanga  71.9667  102.5000     -1.48        93          20       13.76
#
#   Country                 Date
# 0      RU  2022-03-27 02:45:41
# 1      US  2022-03-27 02:43:41
# 2      UY  2022-03-27 02:45:42
# 3      JP  2022-03-27 02:45:42
# 4      SB  2022-03-27 02:45:42
# 5      ID  2022-03-27 02:45:43
# 6      ID  2022-03-27 02:45:43
# 7      CA  2022-03-27 02:45:44
# 8      BR  2022-03-27 02:44:01
# 9      RU  2022-03-27 02:43:38

# %%
# Reordering the columns in the city data dataframe 

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0     Ossora      RU  2022-03-27 02:45:41  59.2353  163.0719     19.47
# 1  Jamestown      US  2022-03-27 02:43:41  42.0970  -79.2353     31.59
# 2       Chuy      UY  2022-03-27 02:45:42 -33.6971  -53.4616     65.44
# 3      Namie      JP  2022-03-27 02:45:42  37.4833  141.0000     57.97
# 4      Buala      SB  2022-03-27 02:45:42  -8.1450  159.5921     80.78
# 5     Sabang      ID  2022-03-27 02:45:43   5.8933   95.3214     82.40
# 6       Tual      ID  2022-03-27 02:45:43  -5.6667  132.7500     82.24
# 7   Barraute      CA  2022-03-27 02:45:44  48.4335  -77.6328     19.67
# 8    Itarema      BR  2022-03-27 02:44:01  -2.9248  -39.9167     75.69
# 9   Khatanga      RU  2022-03-27 02:43:38  71.9667  102.5000     -1.48
#
#    Humidity  Cloudiness  Wind Speed
# 0        77          20        2.04
# 1        71         100       14.97
# 2        76          39       10.02
# 3        62         100       10.87
# 4        82         100        9.84
# 5        75          17        1.54
# 6        76         100       12.82
# 7        93         100       12.62
# 8        91         100        7.23
# 9        93          20       13.76

# %%
# Create the output file (CSV). 
output_data_file = "weather_data/cities.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %% [markdown]
# # Get Data for Plotting

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %% [markdown]
# ### Plot Latitude vs. Temperature

# %%
# Import time module
import time
# Build the scatter plot for latitude vs. max temperature. 
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate other graph properties. 
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure. 
plt.savefig("weather_data/Fig1.png")

# Show plot. 
plt.show()

# %% [markdown]
# ### Plot Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %% [markdown]
# ### Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %% [markdown]
# ### Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %% [markdown]
# ## Find the Correlation Between Latitude and Maximum Temperature

# %%
# Import linregress
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
   # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)

# %% [markdown]
# ##### Note:
# To get an output from a function, we need to call the function with the correct number of parameters or arguments for the function.

# %%
# Create Northern and Southern Hemisphere DataFrames. 
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# ### Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature',
                       'Max Temp',(10,40))

# %% [markdown]
# ### Linear Regression on the Maximum Temperature for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(-45,50))

# %% [markdown]
# ##### Finding
# The correlation between the latitude and the maximum temperature is strong to very strong because the r-value is less than –0.7 for the Northern Hemisphere and greater than 0.7 for the Southern Hemisphere, as shown by the plots here. This means that as we approach the equator, 0° latitude, the temperatures become warmer. And when we are further from the equator the temperatures become cooler. Check the r-values for your plots.

# %% [markdown]
# ### Linear Regression on the Percent Humidity for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity',
                       '% Humidity',(40,10))

# %% [markdown]
# ### Linear Regression on the Percent Humidity for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity',
                       '% Humidity',(-50,15))

# %% [markdown]
# #### Finding:
# The correlation between the latitude and percent humidity is very low because the r-value is less than 0.04 for the Northern and Southern Hemispheres for the plots shown here. This means that percent humidity is unpredictable due to changing weather patterns that can increase or decrease percent humidity. Check the r-values for your plots.

# %% [markdown]
# ### Linear Regression on the Percent Cloudiness for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(10,55))

# %% [markdown]
# ### Linear Regression on the Percent Cloudiness for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(-50,60))

# %% [markdown]
# #### Finding
# The correlation between the latitude and percent cloudiness is very low because the r-value is less than –0.09 for the Northern Hemisphere and less than –0.02 for the Southern Hemisphere for the plots shown here. This means that cloudiness is unpredictable due to changing weather patterns that can increase or decrease percent cloudiness. Check the r-values for your plots.

# %% [markdown]
# ### Linear Regression on the Wind Speed for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed',
                       'Wind Speed',(40,25))

# %% [markdown]
# ### Linear Regression on the Wind Speed for the Southern Hemisphere

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed',
                       'Wind Speed',(-50,25))

# %% [markdown]
# #### Finding:
# The correlation between the latitude and wind speed is very low because the r-value is less  than –0.07 for the Northern Hemisphere and less than –0.3 for the Southern Hemisphere for the plots shown here. This means that wind speed is unpredictable due to changing weather patterns that can increase or decrease wind speed. Check the r-values for your plots.
